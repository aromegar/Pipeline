# %%
import pandas as pd
import seaborn as sns
from src import visual_functions as vf

# %%
sns.set_context("poster")
sns.set(rc={"figure.figsize": (12.,6.)})
sns.set_style("whitegrid")

# %%
df = pd.read_csv("DATA/clean_info.csv")

# %% [markdown]
# ## precios:

# %%
graf1 = sns.barplot(x="City", y="precio_total", data=df)
graf1.set_xticklabels(graf1.get_xticklabels(), rotation=45);

# %% [markdown]
# ## weather:

# %%
for i in range(df.shape[0]):
    city=df.iloc[i].City
    data = vf.ordenadito(city,df.iloc[i].day0, df.iloc[i].day1, df.iloc[i].day2)
#    display(data)

# %%
Bru_df = vf.ordenadito("Bruselas",df.iloc[0].day0, df.iloc[0].day1, df.iloc[0].day2)
Bru_df
# Out:
#       Bruselas                                              d0  \
# 0        T_max                                            11.5
# 1        t_min                                             5.6
# 2  prob_lluvia                                              89
# 3       tiempo                            Patchy rain possible
# 4        icono  //cdn.weatherapi.com/weather/64x64/day/176.png
#
#                                                d1  \
# 0                                            12.9
# 1                                             4.4
# 2                                               0
# 3                                           Sunny
# 4  //cdn.weatherapi.com/weather/64x64/day/113.png
#
#                                                d2
# 0                                            11.5
# 1                                             4.6
# 2                                               0
# 3                                   Partly cloudy
# ...

# %%
from IPython.display import Image, HTML

# %%
# from IPython.core.display import HTML

# %%
Bru_df.iloc[4].d0
# Out:
# '//cdn.weatherapi.com/weather/64x64/day/176.png'

# %%
def path_to_image_html(path):
    return '<img src="'+ path + '" width="60" >'

# %%
Bru_df.to_html(escape=False)
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Bruselas</th>\n      <th>d0</th>\n      <th>d1</th>\n      <th>d2</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>T_max</td>\n      <td>11.5</td>\n      <td>12.9</td>\n      <td>11.5</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>t_min</td>\n      <td>5.6</td>\n      <td>4.4</td>\n      <td>4.6</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>prob_lluvia</td>\n      <td>89</td>\n      <td>0</td>\n      <td>0</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>tiempo</td>\n      <td>Patchy rain possible</td>\n      <td>Sunny</td>\n      <td>Partly cloudy</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>icono</td>\n      <td>//cdn.weatherapi.com/weather/64x64/day/176.png</td>\n      <td>//cdn.weatherapi.com/weather/64x64/day/113.png</td>\n      <td>//cdn.weatherapi.com/weather/64x64/day/116.png</td>\n    </tr>\n  </tbody>
# ...

# %%
ambo = pd.DataFrame(['<img src="image01.png"/>', './image02.png'], columns = ['Image'])

# %%
ambo
# Out:
#                       Image
# 0  <img src="image01.png"/>
# 1             ./image02.png

# %%
HTML(ambo.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Image</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="image01.png"/></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>./image02.png</td>
#     </tr>
#   </tbody>
# </table>

# %%
HTML(Bru_df.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Bruselas</th>
#       <th>d0</th>
#       <th>d1</th>
#       <th>d2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>T_max</td>
#       <td>11.5</td>
#       <td>12.9</td>
#       <td>11.5</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>t_min</td>
#       <td>5.6</td>
#       <td>4.4</td>
#       <td>4.6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>prob_lluvia</td>
#       <td>89</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>tiempo</td>
#       <td>Patchy rain possible</td>
#       <td>Sunny</td>
#       <td>Partly cloudy</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>icono</td>
#       <td>//cdn.weatherapi.com/weather/64x64/day/176.png</td>
#       <td>//cdn.weatherapi.com/weather/64x64/day/113.png</td>
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(20,15))
